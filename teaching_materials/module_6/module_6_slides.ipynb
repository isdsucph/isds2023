# %% [markdown]
# # Session 6: Web Scraping 1

# %% [markdown]
# ## Recap
# In session 5 you briefly touched upon extracting data from the internet
# - You heard about HTTP requests: The computer's way to communicate with the website and underlying server
# - You learned about HTML: The language behind a website
# - You worked with APIs: A way to retrieve structured data from websites
#     - You learned how to send requests to an API and in return receive the desired data
#     - You learned how to deal with the JSON files that is usually how the data is sent

# %% [markdown]
# In the next three sessions we will build on your newly acquired skills
#
# You will learn how to extract data from websites when no API is available
#
# It will open up a whole new world of data possibilities!

# %% [markdown]
# ## Required readings
#
# - [Beautiful Soup: Build a Web Scraper With Python](https://realpython.com/beautiful-soup-web-scraper-python/)
#
# - [A Practical Introduction to Web Scraping in Python](https://realpython.com/python-web-scraping-practical-introduction/)
#
# - Shiab, Nael. 2015. [On the Ethics of Web Scraping and Data Journalism](http://gijn.org/2015/08/12/on-the-ethics-of-web-scraping-and-data-journalism/). Global Investigative Journalism Network.

# %% [markdown]
# ## Overview of Session 6
#
# Today, we will learn about interacting with websites and extracting their unstructured data (web scraping). In particular, we will cover:
# 1. Basics of web scraping:
#     - What is web scraping?
#     - How is a webpage built? How does a computer "see" a webpage?
#     - Ethical considerations
# 2. Mapping the URLs of the webpages you want to scrape:
#     - How can we systematically go through all the webpages and scrape their content?
#         - You will learn to exploit the pattern in the URLs
# 3. Connecting to a webpage:
#     - How do we extract the HTML-string behind the webpage?
# 4. Good practices of web scraping
#     - Limit the rate of your calls to the webpage
#     - Logging
#     - Handle exceptions
# 5. Exploiting the webpage's own data requests to extract data easily
#     - Use the network panel in Chrome Developer Tools to locate the data

# %% [markdown]
# ## What is web scraping?
#
# Web scraping is the practice of extracting information from websites in an automated and structured way
#
# - The internet is the biggest source of information/data you can find! [90% of the data on the internet has been created since 2016](https://blog.microfocus.com/how-much-data-is-created-on-the-internet-each-day/)
# - Web scraping unlock this new world of data possibilities
# - The biggest limitation is your own imagination!

# %% [markdown]
# #### One note:
# - Learning how to web scrape may be frustrating in the beginning
#     - It is a new way of thinking data
#     - It requires technological knowledge
# - Keep working with it!
#     - I promise you; you will master it
#     - And the internet will never be the same again

# %% [markdown]
# ## How a human sees a webpage vs. how a computer sees it

# %% [markdown]
# ### [www.jobnet.dk](https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch)
#
# How a human sees a webpage             |  How a computer sees a webpage
# :-------------------------:|:-------------------------:
# ![](https://drive.google.com/uc?exportview&id=1cbrC303j-gQnXbXyTEQBPT2xH7kgz6Cy)  |  ![](https://drive.google.com/uc?export=view&id=1VFlfDcJHCzbtmkpr4kvXzGecrDE7KmLY)

# %% [markdown]
# ## Ethical Considerations (rule of thumbs)
# 1. Fair use: Take only the stuff you need
# 2. Be careful with copyrighted material
# 3. If a regular user can’t access it, we shouldn’t try to get it: [That is considered hacking](https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking)
# 4. If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from
# 5. LinkedIn case: [Scraping data on LinkedIn is legal](https://gizmodo.com/linkedin-scraping-data-legal-court-case-1848811335)
# 6. Don't hit it too fast: Essentially a DENIAL OF SERVICE attack (DOS); [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb)

# %% [markdown]
# ## The Web Scraping Recipe
#
# Three (main) steps in scraping:
# 1. **MAPPING (this session)**: Find URLs of the webpages containing the information you want.
# 2. **DOWNLOADING (this session)**: Download the HTML of the webpages.
# 3. **PARSING (session 7)**: Extract the information from the HTML.

# %% [markdown]
# ### What browser to use?
# - Lectures and exercises are solely based on Chrome as my browser --> I recommend you to use Chrome as well.
# - All browsers (Chrome, Firefox, Safari, Edge etc.) can be used to investigate the webpages like you will learn to do here
#     - The practice might differ a bit

# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json

# %% [markdown]
# # Video 6.1: Mapping URLs and downloading webpage content

# %% [markdown]
# ## 1. Mapping: How do we find the relevant URLs

# %% [markdown]
# ### Navigating websites to collect links
#
# How can you automate the navigation of links?

# %% [markdown]
# ### Building URLs using a recognizable pattern
# A nice trick is to understand how URLs are constructed to communicate with a server
#
# This will allow us to navigate the page:
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset = 100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %% [markdown]
# Lets look at how [www.jobindex.dk](https://www.jobindex.dk/jobsoegning) does it:
# - We simply click around and take note at how the address line changes

# %% [markdown]
# #### We want to create the URLs for the first 5 pages
# Is there a pattern in the URL that we can exploit?

# %%
links = []
for page in range(1,6,1):
    url = f'https://www.jobindex.dk/jobsoegning?page={page}'
    links.append(url)

# %%
links
# Out:
# ['https://www.jobindex.dk/jobsoegning?page=1',
#  'https://www.jobindex.dk/jobsoegning?page=2',
#  'https://www.jobindex.dk/jobsoegning?page=3',
#  'https://www.jobindex.dk/jobsoegning?page=4',
#  'https://www.jobindex.dk/jobsoegning?page=5']

# %% [markdown]
# ## 2. Connect to the webpage and *download* its content

# %% [markdown]
# ### Here is how you connect to and download the HTML of a webpage

# %%
import requests
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"159a93a5b6c9f025baaf8789c553965bc6b0e098","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"maxdate":20230707,"mindate":20230407},"enable_advanc ...

# %% [markdown]
# #### Remember to tell who you are
# - Write your name and email in the header of the request you send to the webpage
# - Then the managers of the webpage will know you are not a malicious actor

# %%
response = requests.get('https://www.jobindex.dk/jobsoegning?page=1', headers={'name':'Hjalte Fejerskov Boas','email':'hfb@econ.ku.dk'})

# %% [markdown]
# ### We now want to download the content of all 5 links we made earlier

# %%
list_htmls = []
for url in links:
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)

# %%
list_htmls
# Out:
# ['<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"a9f0e6c64ec7db9ee6172ed2c78d87878c27bdb1","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archive":{"maxdate":20230707,"mindate":20230407},"enable_advan ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 2 ud af 948 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=2" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=2" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=2" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"5d13df2ee8d7f7f4e19579a9ecb60d834bd229f8","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archi ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 3 ud af 948 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=3" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=3" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=3" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"35a7941085dc52c378efbe385aec3642284460f1","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archi ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 4 ud af 948 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=4" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=4" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=4" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"54de3223435bb2f37cf72438deae1402a9778b4e","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archi ...
#  '<!DOCTYPE html>\n<html lang="da-DK">\n    \n<head>\n    <title>Ledige job, side 5 ud af 948 | Jobindex</title>\n    <meta content="IE=edge" http-equiv="X-UA-Compatible">\n    <meta charset="UTF-8">\n\n    \n        <link rel="icon" href="/favicon.ico" sizes="any">\n        <link rel="icon" href="/icon.svg" type="image/svg+xml">\n        <link rel="apple-touch-icon" href="/apple-touch-icon.png">\n    <link rel="manifest" href="/manifest.webmanifest">\n\n    <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"><link href="/res/maplibre-gl/dist/maplibre-gl.css?h=0b7aecaa763c9b1b2cb3b2f908ae2456699cad67" rel="stylesheet"><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"><link href="/css/_scss/fonts/roboto.3a7d1284f1971a366212.css" rel="stylesheet"><link href="/css/_scss/fonts/frank_ruhl_libre.fd2b324174c8bfbe93da.css" rel="stylesheet"><link href="/css/_scss/themes/jobindex.8640a1b45e2a32e59225.css" rel="stylesheet">\n\n    <meta content="text/html; charset=UTF-8" http-equiv="content-type"><meta content="da-DK" http-equiv="content-language">\n    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"><meta content="none" name="msapplication-config"><meta content="#b41018" name="theme-color">\n\n\n\n    <script type="application/ld+json">\n        {"@context":"https:\\/\\/schema.org","@type":"WebSite","name":"Jobindex","url":"https:\\/\\/www.jobindex.dk\\/"}\n    </script>\n    <meta content="Jobindex" property="og:site_name">\n    \n    <meta content="https://www.jobindex.dk/jobsoegning?page=5" property="og:url">\n    \n    \n<link href="https://www.jobindex.dk/jobsoegning?page=5" rel="canonical">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="da" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5&amp;lang=en" hreflang="en" rel="alternate">\n<link href="https://www.jobindex.dk/jobsoegning?page=5" hreflang="x-default" rel="alternate">\n\n    <link href="/jobsoegning.rss" rel="alternate nofollow" title="Alle ledige job" type="application/rss+xml">\n\n    <script>//<![CDATA[\n\n    window.JIX = window.JIX || {};\n    (function () {\n        \'use strict\';\n        if (window.JIX.CookieConsent) {\n            return;\n        }\n        \n        function required(cat) {\n            return ["necessary"].indexOf(cat) >= 0;\n        }\n        // In case an ad blocker rejects our real implementation, we\'ll just do nothing and leave people alone.\n        window.JIX.CookieConsent = {\n            hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },\n            whenConsent: function (cat, f) { if (required(cat)) { f(); } },\n        };\n    })();\n\n//]]></script>\n    \n<script>//<![CDATA[\n\n    var Stash = {"common":{"companyuserid":null,"csrf_token":"b09d92202f83d7d45ccc3d399ab156732d3fc615","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex\'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\\/","secure":true},"currentVersion":1,"latestTermsVersion":197,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\\/api\\/cookie-consent\\/v1\\/log"}},"jobagent\\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\\/jobagent\\/virksomhed"},"archi ...

# %% [markdown]
# #### It is good practice to limit the rate of your calls to the website
# You can do that with the function `time.sleep()`

# %%
list_htmls = []
for url in tqdm.tqdm(links): #Track the time left before completing the loop
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:06<00:00,  1.22s/it]

# %% [markdown]
# # Video 6.2: Logging and handling exceptions

# %% [markdown]
# ## Logging
# Logging your web scraping activity is crucial to ensuring and demonstrating data quality. It helps you:
# - to document the data you extract
# - to understand the reasons behind any unexpected stops of your web scraper

# %% [markdown]
# ### Minimum essentials to log
# - *Time* of the scrape
# - The *status code* of the request response
#     - If succesful, the status code is normally *200*
#     - A common error is *404*: "*Page not found*"
# - The *length* of the output
#     - To indicate whether there may be a mistake
#     - In our case the output is usually an HTML-string
# - The *path* to the output file
#     - What did we actually scrape?

# %% [markdown]
# #### Here is a simple logging function that you can use:

# %%
# Define the log function to gather the log information
def log(response,logfile,output_path=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['timestamp','status_code','length','output_file']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    # Gather log information
    status_code = response.status_code #Status code from the request result
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    length = len(response.text) #Length of the HTML-string
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %% [markdown]
# #### Apply to web scrape:

# %%
list_htmls = []
logfile = 'log.csv'
for url in tqdm.tqdm(links):
    response = requests.get(url)
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5)
    log(response,logfile)
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:05<00:00,  1.19s/it]

# %% [markdown]
# ## Handling exceptions
# When you web scrape you will encounter unexpected errors or crashes.
# Some common errors may be:
# - The URL does not exist
# - The connection to the internet stops
#
# How can we mitigate such problems?
# - The `Try/Except` block in python can help us
#     - If the computer encounter an error then it will execute the except code block instead

# %%
list_htmls = []
for url in tqdm.tqdm(links):
    try:
        response = requests.get(url)
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        with open("list_htmls", "w") as l: #Save the list_htmls as a json file to retrieve at another time
            json.dump(list_htmls, l)
        continue #Continue to next iteration of the loop
    html = response.text
    list_htmls.append(html)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:06<00:00,  1.23s/it]

# %% [markdown]
# # Video 6.3: The network panel

# %% [markdown]
# ## Background
# Many webpages are built dynamically
# - Each time you open up the webpage, it sends some **requests** to the server to retrieve the data that you see on the webpage

# %% [markdown]
# We can find these requests and use them!
# - We can then send them directly to the server
# - And then extract the data *before* it is written into the HTML
#     - Much more preferable: The data usually comes in a structured JSON format
#     - Makes it easy to use the data right away

# %% [markdown]
# ## The network panel in Chrome Developer Tools
# Use the **network panel** in the Chrome Developer Tools
# - The network panel monitors all uploads and downloads to and from the webpage
# - I.e. also requests about data we are interested in

# %% [markdown]
# ### The network panel: [www.boligsiden.dk](https://www.boligsiden.dk/tilsalg)
# <img src="https://drive.google.com/uc?export=view&id=1vGk2b1jxH1LU642-YWo1QgR3Q5vz2rQe">

# %% [markdown]
# ### Which request is the one?
# 1. We want to locate an XHR ([XMLHttpRequest](https://en.wikipedia.org/wiki/XMLHttpRequest)). The XHRs transfer data between the server and the webpage
#     - Pick "*Fetch/XHR*"
# 2. Which XHR carries the information about the properties?
#     - We need to look through them all --> You can get a preview of the JSON file in "*Preview*"
# 3. When we have found the right XHR, we need to find the request URL
#     - Go to "*Headers*". Here you see the request URL

# %% [markdown]
# ### The steps:

# %% [markdown]
# #### Send the request to the server and get the data

# %%
response = requests.get('https://api.prod.bs-aws-stage.com/search/cases?addressTypes=villa%2Ccondo%2Cterraced+house%2Choliday+house%2Ccooperative%2Cfarm%2Chobby+farm%2Cfull+year+plot%2Cvilla+apartment%2Choliday+plot&per_page=50&page=1&highlighted=true&sortAscending=true&sortBy=timeOnMarket')

# %% [markdown]
# #### Convert the data to a JSON format in Python

# %%
result = response.json()

# %% [markdown]
# #### The JSON file consists of two different key-value pairs ("cases" and "links").
# #### We are only interested in the information about properties which are stored in the "cases" key-value pair

# %%
result_properties = result['cases']

# %% [markdown]
# #### Now we can easily convert the JSON file to a pandas DataFrame

# %%
data = pd.DataFrame(result_properties)

# %%
data
# Out:
#                                                _links  \
# 0   {'self': {'href': '/cases/1b9cf386-67ef-4b81-9...
# 1   {'self': {'href': '/cases/6b676471-9999-43c6-8...
# 2   {'self': {'href': '/cases/2faa5ba7-9a12-4007-8...
# 3   {'self': {'href': '/cases/7556a1d6-5e31-48bb-9...
# 4   {'self': {'href': '/cases/92aefbc3-4d54-43b3-9...
# 5   {'self': {'href': '/cases/8b9ae609-4d7e-4478-8...
# 6   {'self': {'href': '/cases/c437b537-b585-4caf-9...
# 7   {'self': {'href': '/cases/b25571ce-7878-4f09-8...
# 8   {'self': {'href': '/cases/3390b7ba-227e-4e4e-8...
# 9   {'self': {'href': '/cases/c4f76bcc-c6b8-433b-b...
# 10  {'self': {'href': '/cases/5ce0bca0-5724-4fbd-8...
# 11  {'self': {'href': '/cases/de0051a0-ed3c-4282-a...
# 12  {'self': {'href': '/cases/d6db634c-17e1-4c51-a...
# 13  {'self': {'href': '/cases/be8c23e2-9078-4bed-b...
# 14  {'self': {'href': '/cases/c41423c0-ef13-45c6-8...
# 15  {'self': {'href': '/cases/8e0cae3b-3877-409f-8...
# 16  {'self': {'href': '/cases/cc63c4eb-f32d-4fbb-9...
# 17  {'self': {'href': '/cases/39e2985c-dacf-4d26-b...
# 18  {'self': {'href': '/cases/c3448c22-0afd-4304-a...
# 19  {'self': {'href': '/cases/c084bfa7-2002-4eee-8...
# 20  {'self': {'href': '/cases/a3faaa2a-6343-4183-8...
# 21  {'self': {'href': '/cases/045f327a-07e6-4d74-8...
# 22  {'self': {'href': '/cases/3f55d943-c46d-4eec-8...
# 23  {'self': {'href': '/cases/4d1f5991-11d0-418d-8...
# 24  {'self': {'href': '/cases/6e92a935-bcc5-4047-9...
# 25  {'self': {'href': '/cases/ff38b392-8cc9-4e39-a...
# 26  {'self': {'href': '/cases/17b7ee64-4acd-47e6-a...
# 27  {'self': {'href': '/cases/b4ac3503-432e-41d8-a...
# 28  {'self': {'href': '/cases/dea71fec-c4db-48f0-a...
# 29  {'self': {'href': '/cases/64b19c77-5499-4fe1-9...
# 30  {'self': {'href': '/cases/3f7a561f-14d0-412f-b...
# 31  {'self': {'href': '/cases/50665524-65f9-42b6-a...
# 32  {'self': {'href': '/cases/6173adb2-42a9-4888-a...
# 33  {'self': {'href': '/cases/05cedde9-1ecf-4e8d-9...
# 34  {'self': {'href': '/cases/a3e20eb5-bea7-44fe-b...
# 35  {'self': {'href': '/cases/273468e2-8ffa-4fd8-8...
# 36  {'self': {'href': '/cases/e99ebfa0-c7de-4cad-a...
# 37  {'self': {'href': '/cases/5bf84feb-39f3-4e9f-9...
# 38  {'self': {'href': '/cases/86959e7f-3826-41b7-8...
# 39  {'self': {'href': '/cases/cb6a130c-bc4c-4d30-9...
# 40  {'self': {'href': '/cases/a8a3e822-ed89-4c7f-a...
# 41  {'self': {'href': '/cases/eb953c24-9048-4e64-b...
# 42  {'self': {'href': '/cases/2f2f73a0-bc1a-4a78-9...
# 43  {'self': {'href': '/cases/95e8bcf5-4616-48f3-b...
# 44  {'self': {'href': '/cases/56e99ef1-7ae4-4040-9...
# 45  {'self': {'href': '/cases/847781ca-0494-43c7-a...
# 46  {'self': {'href': '/cases/bdd84db1-688e-4407-b...
# 47  {'self': {'href': '/cases/fa06913f-82e0-4d00-8...
# 48  {'self': {'href': '/cases/f6d83cc0-ab8e-4c3a-9...
# 49  {'self': {'href': '/cases/94057507-fafe-4998-b...
#
#                                               address     addressType  \
# 0   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 1   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 2   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 3   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 4   {'_links': {'self': {'href': '/addresses/0a3f5...            farm
# 5   {'_links': {'self': {'href': '/addresses/fa429...           villa
# 6   {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 7   {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 8   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 9   {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 10  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 11  {'_links': {'self': {'href': '/addresses/0a3f5...            farm
# 12  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 13  {'_links': {'self': {'href': '/addresses/0a3f5...            farm
# 14  {'_links': {'self': {'href': '/addresses/0a3f5...     cooperative
# 15  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 16  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 17  {'_links': {'self': {'href': '/addresses/0a3f5...   holiday house
# 18  {'_links': {'self': {'href': '/addresses/1b1b2...           villa
# 19  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 20  {'_links': {'self': {'href': '/addresses/0a3f5...     cooperative
# 21  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 22  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 23  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 24  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 25  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 26  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 27  {'_links': {'self': {'href': '/addresses/2b3d6...  terraced house
# 28  {'_links': {'self': {'href': '/addresses/c5ca9...  terraced house
# 29  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 30  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 31  {'_links': {'self': {'href': '/addresses/0a3f5...  terraced house
# 32  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 33  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 34  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 35  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 36  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 37  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 38  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 39  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 40  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 41  {'_links': {'self': {'href': '/addresses/39ff9...   holiday house
# 42  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 43  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 44  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 45  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
# 46  {'_links': {'self': {'href': '/addresses/0c656...           villa
# 47  {'_links': {'self': {'href': '/addresses/0a3f5...           condo
# 48  {'_links': {'self': {'href': '/addresses/0a3f5...     cooperative
# 49  {'_links': {'self': {'href': '/addresses/0a3f5...           villa
#
#                                   caseID  \
# 0   1b9cf386-67ef-4b81-9d97-54d0172ea237
# 1   6b676471-9999-43c6-8361-e40b56c1b326
# 2   2faa5ba7-9a12-4007-8738-efbc2a3ae512
# 3   7556a1d6-5e31-48bb-961a-e88700a8a347
# 4   92aefbc3-4d54-43b3-9530-df92d4fe44a4
# 5   8b9ae609-4d7e-4478-8167-8eec15382f39
# 6   c437b537-b585-4caf-94e5-b67c7f0bd9b5
# 7   b25571ce-7878-4f09-817c-06baef565884
# 8   3390b7ba-227e-4e4e-874b-7c0e102f5b9f
# 9   c4f76bcc-c6b8-433b-b8af-50e497625b79
# 10  5ce0bca0-5724-4fbd-82e1-72c6ac839697
# 11  de0051a0-ed3c-4282-a2e7-4d65f0f44928
# 12  d6db634c-17e1-4c51-af14-e35ce413fcdf
# 13  be8c23e2-9078-4bed-b6e2-a9f95611f459
# 14  c41423c0-ef13-45c6-8211-e08217fdf0a1
# 15  8e0cae3b-3877-409f-8f81-a9f821b996cd
# 16  cc63c4eb-f32d-4fbb-9899-50e7e3db175e
# 17  39e2985c-dacf-4d26-b29d-425f14b1b1a2
# 18  c3448c22-0afd-4304-afe2-3eabdd968729
# 19  c084bfa7-2002-4eee-8fa5-d82618846f0e
# 20  a3faaa2a-6343-4183-822b-12abe2c80b5f
# 21  045f327a-07e6-4d74-8aa5-353370d835c3
# 22  3f55d943-c46d-4eec-8838-872317ba8527
# 23  4d1f5991-11d0-418d-8979-37f672b53e72
# 24  6e92a935-bcc5-4047-95c2-2becc53501d6
# 25  ff38b392-8cc9-4e39-ab9b-0b944f67763e
# 26  17b7ee64-4acd-47e6-a1eb-24504ce2b557
# 27  b4ac3503-432e-41d8-a140-3424e72c9dd4
# 28  dea71fec-c4db-48f0-a0f1-c426c65e9cde
# 29  64b19c77-5499-4fe1-99f7-12d16ae7e5dc
# 30  3f7a561f-14d0-412f-b06d-db8b56c5587a
# 31  50665524-65f9-42b6-abab-aa914ecc60de
# 32  6173adb2-42a9-4888-ae4c-62a754f7a3c8
# 33  05cedde9-1ecf-4e8d-9bad-1acd6dddca18
# 34  a3e20eb5-bea7-44fe-b228-4cd2811d9669
# 35  273468e2-8ffa-4fd8-859d-70977d06397e
# 36  e99ebfa0-c7de-4cad-a6b7-4edd98b962a6
# 37  5bf84feb-39f3-4e9f-9169-1d4898d58857
# 38  86959e7f-3826-41b7-8d21-2ddabdd4ce95
# 39  cb6a130c-bc4c-4d30-9013-3d2e6c5f3e7f
# 40  a8a3e822-ed89-4c7f-a310-400ad651cf9e
# 41  eb953c24-9048-4e64-b12d-21ae1fe4f0a8
# 42  2f2f73a0-bc1a-4a78-9c75-2f36213cc70b
# 43  95e8bcf5-4616-48f3-b0fb-ad60425cbd83
# 44  56e99ef1-7ae4-4040-98b8-4697bbb2ae81
# 45  847781ca-0494-43c7-af87-c5362c808237
# 46  bdd84db1-688e-4407-b6da-8231fe53bd04
# 47  fa06913f-82e0-4d00-8033-2a672de6328a
# 48  f6d83cc0-ab8e-4c3a-993a-a4635fe78a08
# 49  94057507-fafe-4998-b1e1-f262ce3583d0
#
#                                               caseUrl  \
# 0   http://www.nybolig.dk/maegler/pages/property-p...
# 1                      https://home.dk/sag/9030001331
# 2   https://www.danbolig.dk?propertyid=0140001772&...
# 3   https://www.danbolig.dk?propertyid=0830000193&...
# 4   https://www.danbolig.dk?propertyid=0140001812&...
# 5   https://www.danbolig.dk?propertyid=0140001022&...
# 6   https://www.danbolig.dk?propertyid=0140001805&...
# 7   https://www.danbolig.dk?propertyid=0350000710&...
# 8   https://www.danbolig.dk?propertyid=0140001832&...
# 9   https://www.danbolig.dk?propertyid=0140001711&...
# 10  https://www.danbolig.dk?propertyid=0140001829&...
# 11  https://www.danbolig.dk?propertyid=0140001853&...
# 12  https://www.danbolig.dk?propertyid=0140001823&...
# 13  https://www.danbolig.dk?propertyid=0140001473&...
# 14  https://www.danbolig.dk?propertyid=2840000405&...
# 15  https://www.danbolig.dk?propertyid=0760000551&...
# 16  http://www.estate-maeglerne.dk/maegler/pages/p...
# 17  https://www.danbolig.dk?propertyid=2840000453&...
# 18  https://www.danbolig.dk?propertyid=0140001798&...
# 19  http://www.estate-maeglerne.dk/maegler/pages/p...
# 20  http://www.nybolig.dk/maegler/pages/property-p...
# 21                     https://home.dk/sag/7190002017
# 22  https://www.danbolig.dk?propertyid=0140001632&...
# 23  https://www.danbolig.dk?propertyid=0350000586&...
# 24  https://www.danbolig.dk?propertyid=0830000280&...
# 25  http://www.estate-maeglerne.dk/maegler/pages/p...
# 26  https://hyllenogco.dk/redirect/?caseno=2813000...
# 27  https://www.danbolig.dk?propertyid=0140001791&...
# 28                     https://home.dk/sag/1220001088
# 29  https://www.danbolig.dk?propertyid=0140001773&...
# 30  https://www.kjeldskov.dk/templates/kjeldskov/i...
# 31            https://www.edc.dk/sag/?sagsnr=26305152
# 32  http://www.nybolig.dk/maegler/pages/property-p...
# 33  http://www.nybolig.dk/maegler/pages/property-p...
# 34  http://www.nybolig.dk/maegler/pages/property-p...
# 35  https://www.danbolig.dk?propertyid=1770000451&...
# 36  http://www.nybolig.dk/maegler/pages/property-p...
# 37  https://www.danbolig.dk?propertyid=0140001408&...
# 38  https://www.danbolig.dk?propertyid=0350000677&...
# 39  https://www.realmaeglerne.dk/301-redirect/?mgl...
# 40  https://www.danbolig.dk?propertyid=3120000366&...
# 41                     https://home.dk/sag/7190002014
# 42  https://www.danbolig.dk?propertyid=1900000656&...
# 43  http://www.nybolig.dk/maegler/pages/property-p...
# 44  https://www.danbolig.dk?propertyid=0830000275&...
# 45  http://www.nybolig.dk/maegler/pages/property-p...
# 46  https://www.danbolig.dk?propertyid=0140001861&...
# 47                     https://home.dk/sag/7190002001
# 48  https://www.danbolig.dk?propertyid=0140001770&...
# 49  https://www.realmaeglerne.dk/301-redirect/?mgl...
#
#                                           coordinates  daysOnMarket  \
# 0   {'lat': 55.250706, 'lon': 11.7673, 'type': 'EP...             1
# 1   {'lat': 55.31548, 'lon': 10.795782, 'type': 'E...             1
# 2   {'lat': 55.766117, 'lon': 11.673014, 'type': '...             1
# 3   {'lat': 55.942894, 'lon': 12.383393, 'type': '...             2
# 4   {'lat': 55.686302, 'lon': 11.713185, 'type': '...             2
# 5   {'lat': 55.54793, 'lon': 11.721237, 'type': 'E...             2
# 6   {'lat': 55.778934, 'lon': 11.805573, 'type': '...             2
# 7   {'lat': 55.85284, 'lon': 12.434458, 'type': 'E...             2
# 8   {'lat': 55.71175, 'lon': 11.720332, 'type': 'E...             2
# 9   {'lat': 55.715332, 'lon': 11.749022, 'type': '...             2
# 10  {'lat': 55.866436, 'lon': 11.54048, 'type': 'E...             3
# 11  {'lat': 55.653084, 'lon': 11.652858, 'type': '...             3
# 12  {'lat': 55.854317, 'lon': 11.518754, 'type': '...             3
# 13  {'lat': 55.6831, 'lon': 11.675904, 'type': 'EP...             3
# 14  {'lat': 55.40592, 'lon': 11.359277, 'type': 'E...             3
# 15  {'lat': 55.77034, 'lon': 12.112547, 'type': 'E...             3
# 16  {'lat': 55.84047, 'lon': 12.265242, 'type': 'E...             3
# 17  {'lat': 55.441654, 'lon': 11.213853, 'type': '...             3
# 18  {'lat': 55.707394, 'lon': 11.758035, 'type': '...             3
# 19  {'lat': 55.94481, 'lon': 12.340236, 'type': 'E...             3
# 20  {'lat': 55.23054, 'lon': 11.783371, 'type': 'E...             4
# 21  {'lat': 55.25351, 'lon': 9.454766, 'type': 'EP...             4
# 22  {'lat': 55.711163, 'lon': 11.663504, 'type': '...             4
# 23  {'lat': 55.839775, 'lon': 12.412554, 'type': '...             4
# 24  {'lat': 55.978745, 'lon': 12.414284, 'type': '...             4
# 25  {'lat': 55.93806, 'lon': 12.315588, 'type': 'E...             4
# 26  {'lat': 55.688572, 'lon': 12.528036, 'type': '...             5
# 27  {'lat': 55.664486, 'lon': 11.554998, 'type': '...             5
# 28  {'lat': 55.827007, 'lon': 12.342629, 'type': '...             6
# 29  {'lat': 55.54725, 'lon': 11.717303, 'type': 'E...             6
# 30  {'lat': 55.51405, 'lon': 12.209229, 'type': 'E...             6
# 31  {'lat': 55.79375, 'lon': 12.486121, 'type': 'E...             7
# 32  {'lat': 55.687748, 'lon': 12.505248, 'type': '...             7
# 33  {'lat': 55.677155, 'lon': 12.537798, 'type': '...             7
# 34  {'lat': 55.392735, 'lon': 11.336642, 'type': '...             7
# 35  {'lat': 55.548775, 'lon': 12.235574, 'type': '...             7
# 36  {'lat': 56.16868, 'lon': 10.219186, 'type': 'E...             7
# 37  {'lat': 55.665573, 'lon': 11.726731, 'type': '...             7
# 38  {'lat': 55.826565, 'lon': 12.428466, 'type': '...             7
# 39  {'lat': 55.38941, 'lon': 10.342532, 'type': 'E...             7
# 40  {'lat': 57.001545, 'lon': 9.820988, 'type': 'E...             7
# 41  {'lat': 55.19355, 'lon': 9.587, 'type': 'EPSG4...             7
# 42  {'lat': 55.564964, 'lon': 12.244517, 'type': '...             7
# 43  {'lat': 55.393864, 'lon': 11.334991, 'type': '...             7
# 44  {'lat': 55.978416, 'lon': 12.415358, 'type': '...             7
# 45  {'lat': 55.463284, 'lon': 11.473054, 'type': '...             7
# 46  {'lat': 55.707844, 'lon': 11.677903, 'type': '...             8
# 47  {'lat': 55.245213, 'lon': 9.479874, 'type': 'E...             8
# 48  {'lat': 55.713932, 'lon': 11.733765, 'type': '...             8
# 49  {'lat': 55.821262, 'lon': 12.012955, 'type': '...             8
#
#                                          defaultImage  \
# 0   {'imageSources': [{'size': {'height': 80, 'wid...
# 1   {'imageSources': [{'size': {'height': 80, 'wid...
# 2   {'imageSources': [{'size': {'height': 80, 'wid...
# 3   {'imageSources': [{'size': {'height': 80, 'wid...
# 4   {'imageSources': [{'size': {'height': 80, 'wid...
# 5   {'imageSources': [{'size': {'height': 80, 'wid...
# 6   {'imageSources': [{'size': {'height': 80, 'wid...
# 7   {'imageSources': [{'size': {'height': 80, 'wid...
# 8   {'imageSources': [{'size': {'height': 80, 'wid...
# 9   {'imageSources': [{'size': {'height': 80, 'wid...
# 10  {'imageSources': [{'size': {'height': 80, 'wid...
# 11  {'imageSources': [{'size': {'height': 80, 'wid...
# 12  {'imageSources': [{'size': {'height': 80, 'wid...
# 13  {'imageSources': [{'size': {'height': 80, 'wid...
# 14  {'imageSources': [{'size': {'height': 80, 'wid...
# 15  {'imageSources': [{'size': {'height': 80, 'wid...
# 16  {'imageSources': [{'size': {'height': 80, 'wid...
# 17  {'imageSources': [{'size': {'height': 80, 'wid...
# 18  {'imageSources': [{'size': {'height': 80, 'wid...
# 19  {'imageSources': [{'size': {'height': 80, 'wid...
# 20  {'imageSources': [{'size': {'height': 80, 'wid...
# 21  {'imageSources': [{'size': {'height': 80, 'wid...
# 22  {'imageSources': [{'size': {'height': 80, 'wid...
# 23  {'imageSources': [{'size': {'height': 80, 'wid...
# 24  {'imageSources': [{'size': {'height': 80, 'wid...
# 25  {'imageSources': [{'size': {'height': 80, 'wid...
# 26  {'imageSources': [{'size': {'height': 80, 'wid...
# 27  {'imageSources': [{'size': {'height': 80, 'wid...
# 28  {'imageSources': [{'size': {'height': 80, 'wid...
# 29  {'imageSources': [{'size': {'height': 80, 'wid...
# 30  {'imageSources': [{'size': {'height': 80, 'wid...
# 31  {'imageSources': [{'size': {'height': 80, 'wid...
# 32  {'imageSources': [{'size': {'height': 80, 'wid...
# 33  {'imageSources': [{'size': {'height': 80, 'wid...
# 34  {'imageSources': [{'size': {'height': 80, 'wid...
# 35  {'imageSources': [{'size': {'height': 80, 'wid...
# 36  {'imageSources': [{'size': {'height': 80, 'wid...
# 37  {'imageSources': [{'size': {'height': 80, 'wid...
# 38  {'imageSources': [{'size': {'height': 80, 'wid...
# 39  {'imageSources': [{'size': {'height': 80, 'wid...
# 40  {'imageSources': [{'size': {'height': 80, 'wid...
# 41  {'imageSources': [{'size': {'height': 80, 'wid...
# 42  {'imageSources': [{'size': {'height': 80, 'wid...
# 43  {'imageSources': [{'size': {'height': 80, 'wid...
# 44  {'imageSources': [{'size': {'height': 80, 'wid...
# 45  {'imageSources': [{'size': {'height': 80, 'wid...
# 46  {'imageSources': [{'size': {'height': 80, 'wid...
# 47  {'imageSources': [{'size': {'height': 80, 'wid...
# 48  {'imageSources': [{'size': {'height': 80, 'wid...
# 49  {'imageSources': [{'size': {'height': 80, 'wid...
#
#                                       descriptionBody  \
# 0   Drømmer I om en skøn villa, hvor I får plads a...
# 1   Det her er sjældent at finde.... Adressen er B...
# 2   I fantastiske omgivelser og med udsigt over vi...
# 3   Grønne, smukke og landlige omgivelser skaber h...
# 4   Tæt på Holbæk har I nu mulighed for at overtag...
# 5   På en lukket vej med nem adgang til hverdagens...
# 6   I Salvig på Orø finder I dette renoverede somm...
# 7   Kunne du tænke dig en nem bolig med egen solri...
# 8   En dejlig beliggenhed tæt på alle hverdagens b...
# 9   I et roligt, eftertragtet kvarter i Holbæk tæt...
# 10  Fantastisk flot sommerhus med udsigt over åbne...
# 11  For enden af en lukket vej med udsigt over gol...
# 12  Glæd jer til at nyde jeres ferier i dette somm...
# 13  Drømmer I om livet på landet? At være omgivet ...
# 14  Attraktiv andelsbolig i hjertet af Slagelse.Vi...
# 15  Velkommen til Harmonivej 3 i Tangbjerg - en fa...
# 16  Villaen på Bøgebakken 1 er højt beliggende for...
# 17  Velkommen til Hjejlevej 15!Stillinge Strand er...
# 18  Med nøgleord som højt til loftet, skønt lysind...
# 19  På Jespervej 214 bliver I en del af et hyggeli...
# 20  På Østre Ringvej 15B finder I denne andelsboli...
# 21  Drømmer du om en lys og moderne bolig med god ...
# 22  Netop nu kan I overtage denne villa i halvande...
# 23  I en af Birkerøds mest efterspurgte og velordn...
# 24  Den 175 m2 store villa i 1,5 plan er bygget i ...
# 25  I det dejligt og fredeligt kvarter, hvor det g...
# 26  Nu kan vi byder jer velkommen til en helt forr...
# 27  Hvis I drømmer om at bo i et aktivt landsbymil...
# 28  I bofællesskabet Holdepunktet, der huser en go...
# 29  Denne velindrettede villa ligger i et roligt, ...
# 30  Med naturskøn beliggenhed på lukket vej i 3 ræ...
# 31  Åbent hus med tilmeldingskrav 9/7 - klik på bi...
# 32  Området: Roligt og attraktivt beliggende lejli...
# 33  Velkommen til Gammel Kongevej 151, den absolut...
# 34  På Kongstedparken 1 i Slagelse udfolder denne ...
# 35  Med en fredelig beliggenhed i Solrød Strand fi...
# 36  Selv i badet har man en tranceagtig udsigt ove...
# 37  Super godt beliggende villa i roligt område på...
# 38  På Nordvanggårdsvej 42 i Bistrup møder I dette...
# 39  Bolbro er et mangfoldigt boligkvarter der emme...
# 40  Velkommen til Leharparken 81 i Frejlev! Denne ...
# 41  Velkommen til Kelstrup Strandvænge 2! Dette so...
# 42  På Bastebjerg 37 i Karlslunde ligger denne fin...
# 43  I et attraktivt og børnevenligt kvarter i det ...
# 44  Den yderst charmerende pudsede villa emmer af ...
# 45  Denne skønne landejendom ligger i flotte omgiv...
# 46  Med kvaliteter som lækkert lysindfald, en dejl...
# 47  I en attraktiv og bynær ejerforening på Erlevv...
# 48  Pæn, velholdt og lys lejlighed nær Ahlgade og ...
# 49  Her på Bygaden 18 i den hyggelige landsby Gerl...
#
#                                      descriptionTitle  ... status  \
# 0   Stor, mulighedsrig villa i attraktive Holsted ...  ...   open
# 1                                              Nyborg  ...   open
# 2      Indflytningsklar villa på naturskønne Tuse Næs  ...   open
# 3   Moderniseret og indflytningsklar villa i natur...  ...   open
# 4   Indflytningsklar landejendom med mange mulighe...  ...   open
# 5   Helt nyt hus med lave varmeudgifter og god ind...  ...   open
# 6                 Flot, moderniseret sommerhus på Orø  ...   open
# 7      Lejlighed med stor have og dejlig grøn udsigt!  ...   open
# 8           Sjældent udbudt adresse centralt i Holbæk  ...   open
# 9                       Lys og nydelig villa i Holbæk  ...   open
# 10      Skønt sommerhus med udsigt til Trundholm Mose  ...   open
# 11  Landejendom med hestehold og udsigt over Midts...  ...   open
# 12  Charmerende sommerhus med idyllisk placering i...  ...   open
# 13  Fantastisk liebhaverejendom med plads til to f...  ...   open
# 14  Moderne og nyrenoveret andelsbolig i centrum a...  ...   open
# 15                     Lækkker indflytningsklar villa  ...   open
# 16  Velholdt og velindrettet familievilla i roligt...  ...   open
# 17  Helårsanvendeligt sommerhus med mulighed for e...  ...   open
# 18  Velbygget funkisvilla på en rolig, lukket vej ...  ...   open
# 19  Hyggelig villa i forskudte plan, med spændende...  ...   open
# 20                  God andelsbolig nær alt i Næstved  ...   open
# 21                                          Haderslev  ...   open
# 22           Dejlig villa med udsigt til Holbæk Fjord  ...   open
# 23                Stor 4V øverst oppe med SKØN altan!  ...   open
# 24  Historisk hus på eftertragtet og børnevenlig v...  ...   open
# 25  Velholdt og attraktivt rækkehus med smuk have ...  ...   open
# 26  Nyt køkken, elevator, p-plads og stor altan på...  ...   open
# 27  Indflytningsklar lejlighed i stemningsfuld sta...  ...   open
# 28  Ønsker du at bo i lækkert gavlrækkehus ud mod ...  ...   open
# 29  Velindrettet villa på en lukket vej i Store Me...  ...   open
# 30  214 m2 forkælet strandvilla i patricierstil i ...  ...   open
# 31  Dejligt rækkehus med særdeles brugbar kælder o...  ...   open
# 32               Stor 2 værelses med vestvendt altan.  ...   open
# 33  INDFLYTNINGSKLAR LEJLIGHED MED SOLRIG SYDVENDT...  ...   open
# 34               2 boligenheder - eller en stor villa  ...   open
# 35  Etplansvilla på hyggelig hjørnegrund i Solrød ...  ...   open
# 36                                                NaN  ...   open
# 37  Villa med fire værelser i roligt kvarter med g...  ...   open
# 38                               X-factor i Birkerød!  ...   open
# 39  STOR OG INDFLYTNINGSKLAR VILLA TIL DEN PLADSKR...  ...   open
# 40  Velindrettet villa i Frejlev med stor garage f...  ...   open
# 41                                    Kelstrup Strand  ...   open
# 42  108 m2 velholdt etplansvilla på skøn, højtplac...  ...   open
# 43         Flot og velholdt villa centralt i Slagelse  ...   open
# 44  Romantisk og charmerende villa med flot have o...  ...   open
# 45                   Skøn villa i landlige omgivelser  ...   open
# 46  Nyere villa i et attraktivt og lukket område i...  ...   open
# 47                                          Haderslev  ...   open
# 48  Pæn, velholdt og lys lejlighed nær Ahlgade og ...  ...   open
# 49  Hyggelig, fint renoveret og indflytningsklar v...  ...   open
#
#                                          timeOnMarket  totalClickCount  \
# 0   {'current': {'days': 1}, 'total': {'days': 1, ...              197
# 1   {'current': {'days': 1}, 'total': {'days': 1, ...              406
# 2   {'current': {'days': 1}, 'total': {'days': 1, ...              299
# 3   {'current': {'days': 2}, 'total': {'days': 178...              570
# 4   {'current': {'days': 2}, 'total': {'days': 167...              429
# 5   {'current': {'days': 2}, 'total': {'days': 2, ...              129
# 6   {'current': {'days': 2}, 'total': {'days': 2, ...              589
# 7   {'current': {'days': 2}, 'total': {'days': 2, ...              155
# 8   {'current': {'days': 2}, 'total': {'days': 2, ...              458
# 9   {'current': {'days': 2}, 'total': {'days': 2, ...              243
# 10  {'current': {'days': 3}, 'total': {'days': 3, ...              279
# 11  {'current': {'days': 3}, 'total': {'days': 3, ...              296
# 12  {'current': {'days': 3}, 'total': {'days': 3, ...              296
# 13  {'current': {'days': 3}, 'total': {'days': 3, ...              909
# 14                           {'current': {'days': 3}}              322
# 15  {'current': {'days': 3}, 'total': {'days': 230...              318
# 16  {'current': {'days': 3}, 'total': {'days': 3, ...              266
# 17  {'current': {'days': 3}, 'total': {'days': 397...              276
# 18  {'current': {'days': 3}, 'total': {'days': 3, ...              539
# 19  {'current': {'days': 3}, 'total': {'days': 3, ...              385
# 20                           {'current': {'days': 4}}              224
# 21  {'current': {'days': 4}, 'total': {'days': 4, ...              440
# 22  {'current': {'days': 4}, 'total': {'days': 4, ...              866
# 23  {'current': {'days': 4}, 'total': {'days': 4, ...              386
# 24  {'current': {'days': 4}, 'total': {'days': 4, ...              387
# 25  {'current': {'days': 4}, 'total': {'days': 4, ...              420
# 26  {'current': {'days': 5}, 'total': {'days': 5, ...              715
# 27  {'current': {'days': 5}, 'total': {'days': 374...              182
# 28  {'current': {'days': 6}, 'total': {'days': 6, ...              575
# 29  {'current': {'days': 6}, 'total': {'days': 6, ...              236
# 30  {'current': {'days': 6}, 'total': {'days': 119...              408
# 31  {'current': {'days': 7}, 'total': {'days': 7, ...              613
# 32  {'current': {'days': 7}, 'total': {'days': 185...              443
# 33  {'current': {'days': 7}, 'total': {'days': 115...              869
# 34  {'current': {'days': 7}, 'total': {'days': 7, ...             1288
# 35  {'current': {'days': 7}, 'total': {'days': 7, ...              371
# 36  {'current': {'days': 7}, 'total': {'days': 7, ...              909
# 37  {'current': {'days': 7}, 'total': {'days': 7, ...              494
# 38  {'current': {'days': 7}, 'total': {'days': 7, ...              994
# 39  {'current': {'days': 7}, 'total': {'days': 419...              428
# 40  {'current': {'days': 7}, 'total': {'days': 7, ...              399
# 41  {'current': {'days': 7}, 'total': {'days': 7, ...              606
# 42  {'current': {'days': 7}, 'total': {'days': 7, ...              371
# 43  {'current': {'days': 7}, 'total': {'days': 7, ...              686
# 44  {'current': {'days': 7}, 'total': {'days': 7, ...              677
# 45  {'current': {'days': 7}, 'total': {'days': 7, ...              205
# 46  {'current': {'days': 8}, 'total': {'days': 363...              242
# 47  {'current': {'days': 8}, 'total': {'days': 8, ...              261
# 48                           {'current': {'days': 8}}              583
# 49  {'current': {'days': 8}, 'total': {'days': 8, ...              552
#
#     totalFavourites     utilitiesConnectionFee  weightedArea  yearBuilt  \
# 0                 2  {'includedInPrice': None}        220.00       1967
# 1                 2  {'includedInPrice': None}        175.00       1924
# 2                 0  {'includedInPrice': None}        111.95       1937
# 3                 7  {'includedInPrice': None}        201.15       1977
# 4                 3  {'includedInPrice': None}        313.45       1870
# 5                 0  {'includedInPrice': None}        172.85       2022
# 6                 5  {'includedInPrice': None}         38.80       1970
# 7                 2  {'includedInPrice': None}           NaN       1959
# 8                 3  {'includedInPrice': None}        167.40       1924
# 9                 1  {'includedInPrice': None}        119.35       1976
# 10                2  {'includedInPrice': None}         72.50       2004
# 11                5  {'includedInPrice': None}        223.90       1930
# 12                6  {'includedInPrice': None}        123.20       1876
# 13                3  {'includedInPrice': None}        106.40       1930
# 14                0  {'includedInPrice': None}           NaN       1863
# 15                5  {'includedInPrice': None}        189.00       1966
# 16                1  {'includedInPrice': None}        130.70       1967
# 17                3  {'includedInPrice': None}         84.45       1978
# 18                2  {'includedInPrice': None}        186.60       2015
# 19                3  {'includedInPrice': None}         97.70       1944
# 20                1  {'includedInPrice': None}           NaN       1953
# 21                2  {'includedInPrice': None}        152.00       1968
# 22                8  {'includedInPrice': None}        124.75       1954
# 23                4  {'includedInPrice': None}           NaN       1959
# 24                1  {'includedInPrice': None}        178.00       1834
# 25                2  {'includedInPrice': None}        140.00       1964
# 26                5  {'includedInPrice': None}           NaN       2005
# 27                0  {'includedInPrice': None}           NaN       1887
# 28                6  {'includedInPrice': None}           NaN       2016
# 29                4  {'includedInPrice': None}        163.00       1978
# 30                1  {'includedInPrice': None}        216.70       1954
# 31                6  {'includedInPrice': None}        105.00       1937
# 32                1  {'includedInPrice': None}           NaN       1936
# 33                7  {'includedInPrice': None}           NaN       1974
# 34                5  {'includedInPrice': None}        164.60       2003
# 35                1  {'includedInPrice': None}        104.00       1952
# 36                4  {'includedInPrice': None}           NaN       1910
# 37                6  {'includedInPrice': None}        144.00       1972
# 38                8  {'includedInPrice': None}        213.45       1932
# 39                3  {'includedInPrice': None}        189.80       1926
# 40                3  {'includedInPrice': None}        164.75       1972
# 41                1  {'includedInPrice': None}        121.60       1977
# 42                0  {'includedInPrice': None}        109.50       1963
# 43                5  {'includedInPrice': None}        167.20       2006
# 44               10  {'includedInPrice': None}        116.25       1920
# 45                0  {'includedInPrice': None}        126.00       1877
# 46                0  {'includedInPrice': None}        153.05       2006
# 47                0  {'includedInPrice': None}           NaN       1966
# 48                1  {'includedInPrice': None}           NaN       1950
# 49                6  {'includedInPrice': None}        138.00       1950
#
#    basementArea  secondaryAddressType  \
# 0           NaN                   NaN
# 1          83.0                   NaN
# 2           3.0                   NaN
# 3          78.0                   NaN
# 4           NaN                   NaN
# 5           NaN                   NaN
# 6           NaN                   NaN
# 7           NaN                   NaN
# 8          56.0                   NaN
# 9           NaN                   NaN
# 10          NaN                   NaN
# 11          NaN                   NaN
# 12          NaN                   NaN
# 13          NaN                 villa
# 14          NaN                   NaN
# 15          NaN                   NaN
# 16          NaN                   NaN
# 17          NaN                   NaN
# 18          NaN                   NaN
# 19         27.0                   NaN
# 20          NaN                   NaN
# 21          NaN                   NaN
# 22          NaN                   NaN
# 23          NaN                   NaN
# 24          NaN                   NaN
# 25         64.0                   NaN
# 26          NaN                   NaN
# 27         40.0                   NaN
# 28          NaN                   NaN
# 29          NaN                   NaN
# 30          NaN                   NaN
# 31         75.0                   NaN
# 32          NaN                   NaN
# 33          NaN                   NaN
# 34          NaN                   NaN
# 35          NaN                   NaN
# 36          NaN                   NaN
# 37          NaN                   NaN
# 38         80.0                   NaN
# 39          NaN                   NaN
# 40          NaN                   NaN
# 41          NaN                   NaN
# 42          NaN                   NaN
# 43          NaN                   NaN
# 44         54.0                   NaN
# 45          NaN                   NaN
# 46          NaN                   NaN
# 47          6.0                   NaN
# 48          NaN                   NaN
# 49          NaN                   NaN
#
#                                           cooperative
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'associationDebt': -532, 'maxPrice': 1145775,...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  {'allocation': 1.51, 'associationDebt': 229509...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48  {'maxPrice': 477478, 'mortgageMaxed': False, '...
# 49                                                NaN
#
# [50 rows x 38 columns]

# %% [markdown]
# ## And we have the data!
